# %%
'''import pandas as pd

from sklearn import linear_model

import matplotlib.pyplot as plt
df=pd.read_csv('hack1.csv')
new=df.fillna(df.mean())

x=new[['Temperature']]
y=new['Power_Output']

# %matplotlib inline
plt.scatter(x, y,color='red',marker='+')
reg=linear_model.LinearRegression()
x=new[['Temperature']]
y=new['Power_Output']
reg.fit(x, y)
plt.plot(new.Temperature,reg.predict(x),color='blue')'''


import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


mock_csv_data = pd.read_csv('hack1.csv')




df['Temperature'] = df['Temperature'].fillna(df['Temperature'].mean())

print(df)


X = df[['Temperature']]
y = df['Power_Output']


model = LinearRegression()
model.fit(X, y)

# %matplotlib inline
plt.scatter(df['Temperature'], df['Power_Output'])
plt.xlabel('Temperature')
plt.ylabel('Power Output')
plt.title('Linear Regression of Power Output vs Temperature')
plt.plot(df['Temperature'], model.predict(X), color='blue')

print('finding the prediction for temparature 30')
print(model.predict([[30]]))
